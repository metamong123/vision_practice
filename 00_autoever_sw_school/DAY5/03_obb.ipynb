# %% [markdown]
# ### Oriented Bounding Box
# - 객체의 방향에 맞춰 회전 가능한 직사각형 박스
# - 일반적으로 중심점, 너비, 높이, 회전 각도로 표현

# %%
import cv2
import numpy as np
from PIL import Image

def show(image):
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return Image.fromarray(rgb)

# %%
from ultralytics import YOLO
model = YOLO('yolo11n-obb.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n-obb.pt to 'yolo11n-obb.pt': 100% ━━━━━━━━━━━━ 5.5MB 23.8MB/s 0.2s.2s<0.0s

# %%
# 이미지 불러오기
import cv2 as cv
img = cv.imread('../data/boats.jpg')

# %%
results = model(img)
show(results[0].plot())
# Out:
# 0: 576x1024 172 ships, 5 harbors, 52.2ms
# Speed: 3.6ms preprocess, 52.2ms inference, 60.3ms postprocess per image at shape (1, 3, 576, 1024)
# <PIL.Image.Image image mode=RGB size=1920x1080>
