# %%
from PIL import Image

# %%
img = Image.open("../data/balloon.webp")
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024>

# %%
img.format
# Out:
# 'WEBP'

# %%
img.size
# Out:
# (1024, 1024)

# %%
img.mode
# Out:
# 'RGB'

# %%
# RGB : 빨강, 초록, 파랑
# RGBA: 빨강, 초록, 파랑 + 투명도(Alpha)
# L   : 흑백
# CMYK: 시안, 마젠타, 노랑, 검정(인쇄용)
img.convert("L") # 이미지를 흑백으로 변환
# Out:
# <PIL.Image.Image image mode=L size=1024x1024>
